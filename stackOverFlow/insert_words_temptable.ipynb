# %%
from flask.ext.sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, ForeignKey
from sqlalchemy.orm import relationship, backref

SQLALCHEMY_DATBASE_URI='sqlite:///tutorial.db'
engine = create_engine(SQLALCHEMY_DATBASE_URI, convert_unicode=True)
metadata = MetaData(bind=engine)
db_session = scoped_session(sessionmaker(autocommit=False,
                                         autoflush=False,
                                         bind=engine))
Base = declarative_base()
Base.query = db_session.query_property()

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, ForeignKey
from sqlalchemy.orm import relationship, backref
#Base = declarative_base()
class Ngrams(Base):
    __tablename__ = 'ngrams'
    __table_args__ = {'extend_existing':True}
    id = Column(Integer,autoincrement=True, primary_key=True)
    questionid = Column(Integer)
    ngrams = Column(String(3500))
    
    def __init__(self,questionid,ngram):
        self.quesionid = questionid
        self.ngram = ngram
    def __repr__(self):
        return '<User %r>' %self.questionid
    
class Phrases(Base):
    __tablename__ = 'phrases'
    __table_args__ = {'extend_existing':True}
    id = Column(Integer,autoincrement=True, primary_key=True)
    phrase = Column(String(3000))
    count = Column(Integer)
    questionids = Column(String(3000))
    
    def __init__(self,phrase,count,ids):
        self.phrase = phrase
        self.count = count
        self.questionids = ids
    def __repr__(self):
        return '<Phrase %r>' %self.phrase

# %%
Base.metadata.create_all(bind=engine)

# %%
def newPhraseInfo(phrase):
    return {"count":0,
        "ids":set(),
        "phrase":phrase
        }

# %%
allphrases = {}
phrase_index= {}
questions = Table('questions', metadata, autoload=True)
con = engine.connect()
r = engine.execute('select * from questions_temp')
data = r.fetchall()
for row in data:
    answer = row[2]
    ans = answer.split()
    for i in range(len(ans)):
        for j in range(i+1, len(ans)+1):
            phrase = " ".join(ans[i:j])
            print phrase
            #phrase = phrase.lower()
            ng = ngrams(row[0],phrase)
            print ng.questionid
            #db_session.add(ng)
            #db_session.commit()
            #print phrase
            #print "----------"
            phrase = phrase.lower()
            if phrase not in allphrases:
                allphrases[phrase] = [phrase.lower()]
                phrase_index[phrase] = newPhraseInfo(phrase)
            #if phrase =="the blue":
                #print "Yes"
                #print phrase_index[phrase]
                #print "======================"
            #phrase_index[phrase] = newPhraseInfo(phrase)
            phrase_index[phrase]["count"] += 1
            phrase_index[phrase]["ids"].add(row[0])
            
           
                
                #phrase_index[phrase]["count"] += 1
                #phrase_index[phrase]["ids"].add(row[0])
# Out:
# The
# None
# The blue
# None
# The blue whale
# None
# The blue whale is
# None
# The blue whale is a
# None
# The blue whale is a very
# None
# The blue whale is a very big
# None
# The blue whale is a very big animal
# None
# The blue whale is a very big animal and
# None
# The blue whale is a very big animal and the
# None
# The blue whale is a very big animal and the blue
# None
# The blue whale is a very big animal and the blue sky
# None
# The blue whale is a very big animal and the blue sky looks
# None
# The blue whale is a very big animal and the blue sky looks very
# None
# The blue whale is a very big animal and the blue sky looks very good
# None
# The blue whale is a very big animal and the blue sky looks very good while
# None
# The blue whale is a very big animal and the blue sky looks very good while the
# None
# The blue whale is a very big animal and the blue sky looks very good while the blue
# None
# The blue whale is a very big animal and the blue sky looks very good while the blue whale
# None
# The blue whale is a very big animal and the blue sky looks very good while the blue whale is
# None
# The blue whale is a very big animal and the blue sky looks very good while the blue whale is swimming
# None
# blue
# None
# blue whale
# None
# blue whale is
# None
# blue whale is a
# None
# blue whale is a very
# None
# blue whale is a very big
# None
# blue whale is a very big animal
# None
# blue whale is a very big animal and
# None
# blue whale is a very big animal and the
# None
# blue whale is a very big animal and the blue
# None
# blue whale is a very big animal and the blue sky
# None
# blue whale is a very big animal and the blue sky looks
# None
# blue whale is a very big animal and the blue sky looks very
# None
# blue whale is a very big animal and the blue sky looks very good
# None
# blue whale is a very big animal and the blue sky looks very good while
# None
# blue whale is a very big animal and the blue sky looks very good while the
# None
# blue whale is a very big animal and the blue sky looks very good while the blue
# None
# blue whale is a very big animal and the blue sky looks very good while the blue whale
# None
# blue whale is a very big animal and the blue sky looks very good while the blue whale is
# None
# blue whale is a very big animal and the blue sky looks very good while the blue whale is swimming
# None
# whale
# None
# whale is
# None
# whale is a
# None
# whale is a very
# None
# whale is a very big
# None
# whale is a very big animal
# None
# whale is a very big animal and
# None
# whale is a very big animal and the
# None
# whale is a very big animal and the blue
# None
# whale is a very big animal and the blue sky
# None
# whale is a very big animal and the blue sky looks
# None
# whale is a very big animal and the blue sky looks very
# None
# whale is a very big animal and the blue sky looks very good
# None
# whale is a very big animal and the blue sky looks very good while
# None
# whale is a very big animal and the blue sky looks very good while the
# None
# whale is a very big animal and the blue sky looks very good while the blue
# None
# whale is a very big animal and the blue sky looks very good while the blue whale
# None
# whale is a very big animal and the blue sky looks very good while the blue whale is
# None
# whale is a very big animal and the blue sky looks very good while the blue whale is swimming
# None
# is
# None
# is a
# None
# is a very
# None
# is a very big
# None
# is a very big animal
# None
# is a very big animal and
# None
# is a very big animal and the
# None
# is a very big animal and the blue
# None
# is a very big animal and the blue sky
# None
# is a very big animal and the blue sky looks
# None
# is a very big animal and the blue sky looks very
# None
# is a very big animal and the blue sky looks very good
# None
# is a very big animal and the blue sky looks very good while
# None
# is a very big animal and the blue sky looks very good while the
# None
# is a very big animal and the blue sky looks very good while the blue
# None
# is a very big animal and the blue sky looks very good while the blue whale
# None
# is a very big animal and the blue sky looks very good while the blue whale is
# None
# is a very big animal and the blue sky looks very good while the blue whale is swimming
# None
# a
# None
# a very
# None
# a very big
# None
# a very big animal
# None
# a very big animal and
# None
# a very big animal and the
# None
# a very big animal and the blue
# None
# a very big animal and the blue sky
# None
# a very big animal and the blue sky looks
# None
# a very big animal and the blue sky looks very
# None
# a very big animal and the blue sky looks very good
# None
# a very big animal and the blue sky looks very good while
# None
# a very big animal and the blue sky looks very good while the
# None
# a very big animal and the blue sky looks very good while the blue
# None
# a very big animal and the blue sky looks very good while the blue whale
# None
# a very big animal and the blue sky looks very good while the blue whale is
# None
# a very big animal and the blue sky looks very good while the blue whale is swimming
# None
# very
# None
# very big
# None
# very big animal
# None
# very big animal and
# None
# very big animal and the
# None
# very big animal and the blue
# None
# very big animal and the blue sky
# None
# very big animal and the blue sky looks
# None
# very big animal and the blue sky looks very
# None
# very big animal and the blue sky looks very good
# None
# very big animal and the blue sky looks very good while
# None
# very big animal and the blue sky looks very good while the
# None
# very big animal and the blue sky looks very good while the blue
# None
# very big animal and the blue sky looks very good while the blue whale
# None
# very big animal and the blue sky looks very good while the blue whale is
# None
# very big animal and the blue sky looks very good while the blue whale is swimming
# None
# big
# None
# big animal
# None
# big animal and
# None
# big animal and the
# None
# big animal and the blue
# None
# big animal and the blue sky
# None
# big animal and the blue sky looks
# None
# big animal and the blue sky looks very
# None
# big animal and the blue sky looks very good
# None
# big animal and the blue sky looks very good while
# None
# big animal and the blue sky looks very good while the
# None
# big animal and the blue sky looks very good while the blue
# None
# big animal and the blue sky looks very good while the blue whale
# None
# big animal and the blue sky looks very good while the blue whale is
# None
# big animal and the blue sky looks very good while the blue whale is swimming
# None
# animal
# None
# animal and
# None
# animal and the
# None
# animal and the blue
# None
# animal and the blue sky
# None
# animal and the blue sky looks
# None
# animal and the blue sky looks very
# None
# animal and the blue sky looks very good
# None
# animal and the blue sky looks very good while
# None
# animal and the blue sky looks very good while the
# None
# animal and the blue sky looks very good while the blue
# None
# animal and the blue sky looks very good while the blue whale
# None
# animal and the blue sky looks very good while the blue whale is
# None
# animal and the blue sky looks very good while the blue whale is swimming
# None
# and
# None
# and the
# None
# and the blue
# None
# and the blue sky
# None
# and the blue sky looks
# None
# and the blue sky looks very
# None
# and the blue sky looks very good
# None
# and the blue sky looks very good while
# None
# and the blue sky looks very good while the
# None
# and the blue sky looks very good while the blue
# None
# and the blue sky looks very good while the blue whale
# None
# and the blue sky looks very good while the blue whale is
# None
# and the blue sky looks very good while the blue whale is swimming
# None
# the
# None
# the blue
# None
# the blue sky
# None
# the blue sky looks
# None
# the blue sky looks very
# None
# the blue sky looks very good
# None
# the blue sky looks very good while
# None
# the blue sky looks very good while the
# None
# the blue sky looks very good while the blue
# None
# the blue sky looks very good while the blue whale
# None
# the blue sky looks very good while the blue whale is
# None
# the blue sky looks very good while the blue whale is swimming
# None
# blue
# None
# blue sky
# None
# blue sky looks
# None
# blue sky looks very
# None
# blue sky looks very good
# None
# blue sky looks very good while
# None
# blue sky looks very good while the
# None
# blue sky looks very good while the blue
# None
# blue sky looks very good while the blue whale
# None
# blue sky looks very good while the blue whale is
# None
# blue sky looks very good while the blue whale is swimming
# None
# sky
# None
# sky looks
# None
# sky looks very
# None
# sky looks very good
# None
# sky looks very good while
# None
# sky looks very good while the
# None
# sky looks very good while the blue
# None
# sky looks very good while the blue whale
# None
# sky looks very good while the blue whale is
# None
# sky looks very good while the blue whale is swimming
# None
# looks
# None
# looks very
# None
# looks very good
# None
# looks very good while
# None
# looks very good while the
# None
# looks very good while the blue
# None
# looks very good while the blue whale
# None
# looks very good while the blue whale is
# None
# looks very good while the blue whale is swimming
# None
# very
# None
# very good
# None
# very good while
# None
# very good while the
# None
# very good while the blue
# None
# very good while the blue whale
# None
# very good while the blue whale is
# None
# very good while the blue whale is swimming
# None
# good
# None
# good while
# None
# good while the
# None
# good while the blue
# None
# good while the blue whale
# None
# good while the blue whale is
# None
# good while the blue whale is swimming
# None
# while
# None
# while the
# None
# while the blue
# None
# while the blue whale
# None
# while the blue whale is
# None
# while the blue whale is swimming
# None
# the
# None
# the blue
# None
# the blue whale
# None
# the blue whale is
# None
# the blue whale is swimming
# None
# blue
# None
# blue whale
# None
# blue whale is
# None
# blue whale is swimming
# None
# whale
# None
# whale is
# None
# whale is swimming
# None
# is
# None
# is swimming
# None
# swimming
# None
# The
# None
# The weather
# None
# The weather is
# None
# The weather is bright,
# None
# The weather is bright, and
# None
# The weather is bright, and it
# None
# The weather is bright, and it is
# None
# The weather is bright, and it is time
# None
# The weather is bright, and it is time to
# None
# The weather is bright, and it is time to go
# None
# The weather is bright, and it is time to go for
# None
# The weather is bright, and it is time to go for picnic
# None
# weather
# None
# weather is
# None
# weather is bright,
# None
# weather is bright, and
# None
# weather is bright, and it
# None
# weather is bright, and it is
# None
# weather is bright, and it is time
# None
# weather is bright, and it is time to
# None
# weather is bright, and it is time to go
# None
# weather is bright, and it is time to go for
# None
# weather is bright, and it is time to go for picnic
# None
# is
# None
# is bright,
# None
# is bright, and
# None
# is bright, and it
# None
# is bright, and it is
# None
# is bright, and it is time
# None
# is bright, and it is time to
# None
# is bright, and it is time to go
# None
# is bright, and it is time to go for
# None
# is bright, and it is time to go for picnic
# None
# bright,
# None
# bright, and
# None
# bright, and it
# None
# bright, and it is
# None
# bright, and it is time
# None
# bright, and it is time to
# None
# bright, and it is time to go
# None
# bright, and it is time to go for
# None
# bright, and it is time to go for picnic
# None
# and
# None
# and it
# None
# and it is
# None
# and it is time
# None
# and it is time to
# None
# and it is time to go
# None
# and it is time to go for
# None
# and it is time to go for picnic
# None
# it
# None
# it is
# None
# it is time
# None
# it is time to
# None
# it is time to go
# None
# it is time to go for
# None
# it is time to go for picnic
# None
# is
# None
# is time
# None
# is time to
# None
# is time to go
# None
# is time to go for
# None
# is time to go for picnic
# None
# time
# None
# time to
# None
# time to go
# None
# time to go for
# None
# time to go for picnic
# None
# to
# None
# to go
# None
# to go for
# None
# to go for picnic
# None
# go
# None
# go for
# None
# go for picnic
# None
# for
# None
# for picnic
# None
# picnic
# None
# The
# None
# The weather
# None
# The weather is
# None
# The weather is bright,
# None
# The weather is bright, and
# None
# The weather is bright, and it
# None
# The weather is bright, and it is
# None
# The weather is bright, and it is time
# None
# The weather is bright, and it is time to
# None
# The weather is bright, and it is time to go
# None
# The weather is bright, and it is time to go for
# None
# The weather is bright, and it is time to go for picnic,
# None
# The weather is bright, and it is time to go for picnic, the
# None
# The weather is bright, and it is time to go for picnic, the blue
# None
# The weather is bright, and it is time to go for picnic, the blue sky
# None
# The weather is bright, and it is time to go for picnic, the blue sky and
# None
# The weather is bright, and it is time to go for picnic, the blue sky and blue
# None
# The weather is bright, and it is time to go for picnic, the blue sky and blue cafe
# None
# weather
# None
# weather is
# None
# weather is bright,
# None
# weather is bright, and
# None
# weather is bright, and it
# None
# weather is bright, and it is
# None
# weather is bright, and it is time
# None
# weather is bright, and it is time to
# None
# weather is bright, and it is time to go
# None
# weather is bright, and it is time to go for
# None
# weather is bright, and it is time to go for picnic,
# None
# weather is bright, and it is time to go for picnic, the
# None
# weather is bright, and it is time to go for picnic, the blue
# None
# weather is bright, and it is time to go for picnic, the blue sky
# None
# weather is bright, and it is time to go for picnic, the blue sky and
# None
# weather is bright, and it is time to go for picnic, the blue sky and blue
# None
# weather is bright, and it is time to go for picnic, the blue sky and blue cafe
# None
# is
# None
# is bright,
# None
# is bright, and
# None
# is bright, and it
# None
# is bright, and it is
# None
# is bright, and it is time
# None
# is bright, and it is time to
# None
# is bright, and it is time to go
# None
# is bright, and it is time to go for
# None
# is bright, and it is time to go for picnic,
# None
# is bright, and it is time to go for picnic, the
# None
# is bright, and it is time to go for picnic, the blue
# None
# is bright, and it is time to go for picnic, the blue sky
# None
# is bright, and it is time to go for picnic, the blue sky and
# None
# is bright, and it is time to go for picnic, the blue sky and blue
# None
# is bright, and it is time to go for picnic, the blue sky and blue cafe
# None
# bright,
# None
# bright, and
# None
# bright, and it
# None
# bright, and it is
# None
# bright, and it is time
# None
# bright, and it is time to
# None
# bright, and it is time to go
# None
# bright, and it is time to go for
# None
# bright, and it is time to go for picnic,
# None
# bright, and it is time to go for picnic, the
# None
# bright, and it is time to go for picnic, the blue
# None
# bright, and it is time to go for picnic, the blue sky
# None
# bright, and it is time to go for picnic, the blue sky and
# None
# bright, and it is time to go for picnic, the blue sky and blue
# None
# bright, and it is time to go for picnic, the blue sky and blue cafe
# None
# and
# None
# and it
# None
# and it is
# None
# and it is time
# None
# and it is time to
# None
# and it is time to go
# None
# and it is time to go for
# None
# and it is time to go for picnic,
# None
# and it is time to go for picnic, the
# None
# and it is time to go for picnic, the blue
# None
# and it is time to go for picnic, the blue sky
# None
# and it is time to go for picnic, the blue sky and
# None
# and it is time to go for picnic, the blue sky and blue
# None
# and it is time to go for picnic, the blue sky and blue cafe
# None
# it
# None
# it is
# None
# it is time
# None
# it is time to
# None
# it is time to go
# None
# it is time to go for
# None
# it is time to go for picnic,
# None
# it is time to go for picnic, the
# None
# it is time to go for picnic, the blue
# None
# it is time to go for picnic, the blue sky
# None
# it is time to go for picnic, the blue sky and
# None
# it is time to go for picnic, the blue sky and blue
# None
# it is time to go for picnic, the blue sky and blue cafe
# None
# is
# None
# is time
# None
# is time to
# None
# is time to go
# None
# is time to go for
# None
# is time to go for picnic,
# None
# is time to go for picnic, the
# None
# is time to go for picnic, the blue
# None
# is time to go for picnic, the blue sky
# None
# is time to go for picnic, the blue sky and
# None
# is time to go for picnic, the blue sky and blue
# None
# is time to go for picnic, the blue sky and blue cafe
# None
# time
# None
# time to
# None
# time to go
# None
# time to go for
# None
# time to go for picnic,
# None
# time to go for picnic, the
# None
# time to go for picnic, the blue
# None
# time to go for picnic, the blue sky
# None
# time to go for picnic, the blue sky and
# None
# time to go for picnic, the blue sky and blue
# None
# time to go for picnic, the blue sky and blue cafe
# None
# to
# None
# to go
# None
# to go for
# None
# to go for picnic,
# None
# to go for picnic, the
# None
# to go for picnic, the blue
# None
# to go for picnic, the blue sky
# None
# to go for picnic, the blue sky and
# None
# to go for picnic, the blue sky and blue
# None
# to go for picnic, the blue sky and blue cafe
# None
# go
# None
# go for
# None
# go for picnic,
# None
# go for picnic, the
# None
# go for picnic, the blue
# None
# go for picnic, the blue sky
# None
# go for picnic, the blue sky and
# None
# go for picnic, the blue sky and blue
# None
# go for picnic, the blue sky and blue cafe
# None
# for
# None
# for picnic,
# None
# for picnic, the
# None
# for picnic, the blue
# None
# for picnic, the blue sky
# None
# for picnic, the blue sky and
# None
# for picnic, the blue sky and blue
# None
# for picnic, the blue sky and blue cafe
# None
# picnic,
# None
# picnic, the
# None
# picnic, the blue
# None
# picnic, the blue sky
# None
# picnic, the blue sky and
# None
# picnic, the blue sky and blue
# None
# picnic, the blue sky and blue cafe
# None
# the
# None
# the blue
# None
# the blue sky
# None
# the blue sky and
# None
# the blue sky and blue
# None
# the blue sky and blue cafe
# None
# blue
# None
# blue sky
# None
# blue sky and
# None
# blue sky and blue
# None
# blue sky and blue cafe
# None
# sky
# None
# sky and
# None
# sky and blue
# None
# sky and blue cafe
# None
# and
# None
# and blue
# None
# and blue cafe
# None
# blue
# None
# blue cafe
# None
# cafe
# None
# 1,2,3,4,5
# None

# %%
for unique_phrases in phrase_index.keys():
    ph = phrases(unique_phrases[phrase], unique_phrases[phrase]["count"],unique_phrases[phrase]["ids"])
    db_session.add(ph)
    db_session.commit()

# %%
phrase_index

# %%
questions = Table('questions', metadata, autoload=True)
con = engine.connect()
r = engine.execute('select * from questions_temp where ques_id =4')
data = r.fetchall()
for i in data:
    x = i[2].split()
print x
